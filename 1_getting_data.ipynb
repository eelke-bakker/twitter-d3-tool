# %%
import pandas as pd
import json
import subprocess
import re
import ast

# %% [markdown]
# ### Get tweets from users' timelines

# %%
address = "data/concatenated_tweets.csv"

data = pd.read_csv(address)
data.head()
# Out:
#             created_at                   id               id_str  \
# 0  2020-09-14 21:29:41  1305619753617231874  1305619753617231874
# 1  2020-09-14 21:29:41  1305619753021706241  1305619753021706241
# 2  2020-09-14 21:29:40  1305619752824565762  1305619752824565762
# 3  2020-09-14 21:29:40  1305619752497418240  1305619752497418240
# 4  2020-09-14 21:29:40  1305619751977320463  1305619751977320463
#
#                                                 text  truncated  \
# 0  @realDonaldTrump LIAR LIAR LIAR LIAR LIAR LIAR...      False
# 1  @realDonaldTrump @FoxNews Dump you jealous you...      False
# 2  @realDonaldTrump @FoxNews Have the military en...      False
# 3  RT @Nostradonny: @realDonaldTrump https://t.co...      False
# 4  @realDonaldTrump @FoxNews You don't get to dic...       True
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata               source  \
# 0  {'iso_language_code': 'ro', 'result_type': 're...  Twitter for Android
# 1  {'iso_language_code': 'en', 'result_type': 're...   Twitter for iPhone
# 2  {'iso_language_code': 'en', 'result_type': 're...  Twitter for Android
# 3  {'iso_language_code': 'und', 'result_type': 'r...      Twitter Web App
# 4  {'iso_language_code': 'en', 'result_type': 're...      Twitter Web App
#
#                             source_url  in_reply_to_status_id  ...  \
# 0  http://twitter.com/download/android           1.305152e+18  ...
# 1   http://twitter.com/download/iphone           1.305618e+18  ...
# 2  http://twitter.com/download/android           1.305618e+18  ...
# 3           https://mobile.twitter.com                    NaN  ...
# 4           https://mobile.twitter.com           1.305618e+18  ...
#
#    has_extended_profile  default_profile  default_profile_image following  \
# 0                 False             True                   True     False
# 1                  True             True                  False     False
# 2                  True             True                  False     False
# 3                 False            False                  False     False
# 4                 False             True                  False     False
#
#   follow_request_sent notifications  translator_type  \
# 0               False         False             none
# 1               False         False             none
# 2               False         False             none
# 3               False         False             none
# 4               False         False             none
#
#    entities.description.urls  \
# 0                         []
# 1                         []
# 2                         []
# 3                         []
# 4                         []
#
#                                   profile_banner_url  entities.url.urls
# 0                                                NaN                NaN
# 1  https://pbs.twimg.com/profile_banners/12714658...                NaN
# 2  https://pbs.twimg.com/profile_banners/11877707...                NaN
# 3  https://pbs.twimg.com/profile_banners/88044592...                NaN
# 4  https://pbs.twimg.com/profile_banners/88665262...                NaN
#
# [5 rows x 82 columns]

# %%
usernames = data["screen_name"].values

# %%
# loop through usernames, get their tweet data, and save to file

for username in usernames:
    command = "twint -u " + username + " -o data/tweets.csv --csv --limit 1"
    subprocess.call(command, shell=True)
