# %%
import pandas as pd
import json

# %% [markdown]
# ### Flatten dictionary columns for current twitter data

# %%
address2 = "replies_clean.csv"

data2 = pd.read_csv(address2)
data2.head()
# Out:
#             created_at                   id               id_str  \
# 0  2020-09-14 21:01:37  1305612690396557313  1305612690396557313
# 1  2020-09-14 21:01:37  1305612689796808704  1305612689796808704
# 2  2020-09-14 21:01:36  1305612689532768257  1305612689532768257
# 3  2020-09-14 21:01:36  1305612688823902210  1305612688823902210
# 4  2020-09-14 21:01:36  1305612688542887937  1305612688542887937
#
#                                                 text  truncated  \
# 0  @realDonaldTrump I am in India.\nGood Night Pr...      False
# 1           @realDonaldTrump https://t.co/LEW29t4Tad      False
# 2  @realDonaldTrump The guy who lies about everyt...      False
# 3  @realDonaldTrump Thank goodness!!!!! He’s dest...      False
# 4  @realDonaldTrump Okay Mr. Trees Explode 🙄\nThe...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   created_at                 5 non-null      object
#  1   id                         5 non-null      int64
#  2   id_str                     5 non-null      int64
#  3   text                       5 non-null      object
#  4   truncated                  5 non-null      bool
#  5   entities                   5 non-null      object
#  6   metadata                   5 non-null      object
#  7   source                     5 non-null      object
#  8   source_url                 5 non-null      object
#  9   in_reply_to_status_id      5 non-null      int64
#  10  in_reply_to_status_id_str  5 non-null      int64
#  11  in_reply_to_user_id        5 non-null      int64
#  12  in_reply_to_user_id_str    5 non-null      int64
# ...

# %%
data2["entities"] = data2["entities"].apply(lambda x: x.replace("'", "\""))
data2["metadata"] = data2["metadata"].apply(lambda x: x.replace("'", "\""))

# %%
df_list = [data2, pd.json_normalize(data2["entities"].apply(json.loads)), pd.json_normalize(data2["metadata"].apply(json.loads)), pd.json_normalize(data2["user"].apply(json.loads))]

# %%
concatenated = pd.concat(df_list, axis=1)

# %%
concatenated.head()
# Out:
#             created_at                   id               id_str  \
# 0  2020-09-14 21:01:37  1305612690396557313  1305612690396557313
# 1  2020-09-14 21:01:37  1305612689796808704  1305612689796808704
# 2  2020-09-14 21:01:36  1305612689532768257  1305612689532768257
# 3  2020-09-14 21:01:36  1305612688823902210  1305612688823902210
# 4  2020-09-14 21:01:36  1305612688542887937  1305612688542887937
#
#                                                 text  truncated  \
# 0  @realDonaldTrump I am in India.\nGood Night Pr...      False
# 1           @realDonaldTrump https://t.co/LEW29t4Tad      False
# 2  @realDonaldTrump The guy who lies about everyt...      False
# 3  @realDonaldTrump Thank goodness!!!!! He’s dest...      False
# 4  @realDonaldTrump Okay Mr. Trees Explode 🙄\nThe...      False
#
#                                             entities  \
# 0  {"hashtags": [], "symbols": [], "user_mentions...
# 1  {"hashtags": [], "symbols": [], "user_mentions...
# ...

# %%
concatenated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 82 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   created_at                          5 non-null      object
#  1   id                                  5 non-null      int64
#  2   id_str                              5 non-null      int64
#  3   text                                5 non-null      object
#  4   truncated                           5 non-null      bool
#  5   entities                            5 non-null      object
#  6   metadata                            5 non-null      object
#  7   source                              5 non-null      object
#  8   source_url                          5 non-null      object
#  9   in_reply_to_status_id               5 non-null      int64
#  10  in_reply_to_status_id_str           5 non-null      int64
# ...

# %%
#concatenated.to_csv("concatenated_tweets.csv", index=False)
